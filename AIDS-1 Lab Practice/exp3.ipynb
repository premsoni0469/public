# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Rahul Soni/Downloads/StudentsPerformance.csv')

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (1000, 8)

# %%
train_data = df.sample(frac=0.75, random_state=0)
test_data = df.drop(training_data.index)

print("Training Data Size: ", train_data.shape)
print("Testing Data Size: ", test_data.shape)
# Out:
# Training Data Size:  (750, 8)
# Testing Data Size:  (250, 8)

# %%
from sklearn.model_selection import train_test_split
training_data, testing_data = train_test_split(df, test_size=0.25, random_state=0 )
training_data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 253    male        group D             master's degree      standard
# 667  female        group B           bachelor's degree  free/reduced
# 85   female        group C                some college      standard
# 969  female        group B           bachelor's degree      standard
# 75     male        group B          associate's degree  free/reduced
# ..      ...            ...                         ...           ...
# 835  female        group C                 high school      standard
# 192  female        group B            some high school      standard
# 629  female        group C            some high school      standard
# 559    male        group D            some high school      standard
# 684    male        group B                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
testing_data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 993  female        group D           bachelor's degree  free/reduced
# 859    male        group C          associate's degree  free/reduced
# 298    male        group C                 high school  free/reduced
# 553    male        group D                some college  free/reduced
# 672  female        group C                some college      standard
# ..      ...            ...                         ...           ...
# 462  female        group E                some college      standard
# 356    male        group A          associate's degree      standard
# 2    female        group B             master's degree      standard
# 478  female        group D             master's degree      standard
# 695  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
print("No of training sample: ", training_data.shape)
print("No of testing sample: ", testing_data.shape)
# Out:
# No of training sample:  (750, 8)
# No of testing sample:  (250, 8)

# %%
training_data.head(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 253    male        group D             master's degree      standard
# 667  female        group B           bachelor's degree  free/reduced
# 85   female        group C                some college      standard
# 969  female        group B           bachelor's degree      standard
# 75     male        group B          associate's degree  free/reduced
# 786  female        group E            some high school  free/reduced
# 658  female        group D          associate's degree  free/reduced
# 465  female        group C                some college      standard
# 920    male        group D                 high school  free/reduced
# 38   female        group D          associate's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 253                    none          80             80             72
# ...

# %%
Y_train = training_data['math score']
Y_train
# Out:
# 253    80
# 667    77
# 85     73
# 969    75
# 75     44
#        ..
# 835    60
# 192    62
# 629    44
# 559    73
# 684    62
# Name: math score, Length: 750, dtype: int64

# %%
training_data.drop(['math score'], axis=1, inplace=True)
training_data.head()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 253    male        group D             master's degree      standard
# 667  female        group B           bachelor's degree  free/reduced
# 85   female        group C                some college      standard
# 969  female        group B           bachelor's degree      standard
# 75     male        group B          associate's degree  free/reduced
#
#     test preparation course  reading score  writing score
# 253                    none             80             72
# 667                    none             85             87
# 85                     none             80             82
# 969                    none             84             80
# 75                     none             41             38

# %%
testing_data.head(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 993  female        group D           bachelor's degree  free/reduced
# 859    male        group C          associate's degree  free/reduced
# 298    male        group C                 high school  free/reduced
# 553    male        group D                some college  free/reduced
# 672  female        group C                some college      standard
# 971    male        group C            some high school      standard
# 27   female        group C           bachelor's degree      standard
# 231    male        group C          associate's degree      standard
# 306    male        group E                some college      standard
# 706    male        group D                 high school      standard
#
#     test preparation course  math score  reading score  writing score
# 993                    none          62             72             74
# ...

# %%
Y_test = testing_data['math score']
testing_data.drop(['math score'], axis=1, inplace=True)
testing_data.head()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 993  female        group D           bachelor's degree  free/reduced
# 859    male        group C          associate's degree  free/reduced
# 298    male        group C                 high school  free/reduced
# 553    male        group D                some college  free/reduced
# 672  female        group C                some college      standard
#
#     test preparation course  reading score  writing score
# 993                    none             72             74
# 859                    none             73             72
# 298               completed             46             50
# 553                    none             62             64
# 672                    none             78             76

# %%
Y_train.head()
# Out:
# 253    80
# 667    77
# 85     73
# 969    75
# 75     44
# Name: math score, dtype: int64

# %%
Y_test.head()
# Out:
# 993    62
# 859    87
# 298    40
# 553    77
# 672    69
# Name: math score, dtype: int64

# %%
import matplotlib.pyplot as plt
value=[training_data.shape[0], testing_data.shape[0]]
label=['Train', 'Test']
plt.bar(label, value)
# Out:
# <BarContainer object of 2 artists>

# %%
import math
x = Y_train.mean()
y = Y_test.mean()
d = 0

s1 = Y_train.std()
s2 = Y_test.std()

n1 = training_data.shape[0]
n2 = testing_data.shape[0]

print(x, y, d, s1, s2, n1, n2)
# Out:
# 66.34266666666667 65.328 0 15.286272918598506 14.791333618061735 750 250

# %%
z = (x - y - d) / math.sqrt( (s1**2 / n1) + (s2**2 / n2))

print(z)
# Out:
# 0.9314379942900398

# %%
from statsmodels.stats.weightstats import ztest

# %%
ztest , pval1 = ztest(Y_train, Y_test, value=0, alternative='two-sided')

# %%
print(ztest, pval1)
# Out:
# 0.9162240834679604 0.3595493763059957
