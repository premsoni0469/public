# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Rahul Soni/Downloads/SampleSuperstore.csv')

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 17

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
pd.crosstab(index=df['Region'], columns=df['Postal Code'])
# Out:
# Postal Code  1040   1453   1752   1810   1841   1852   1915   2038   2138   \
# Region
# Central          0      0      0      0      0      0      0      0      0
# East             1      6      2      4     33     16      3     17      6
# South            0      0      0      0      0      0      0      0      0
# West             0      0      0      0      0      0      0      0      0
#
# Postal Code  2148   ...  98115  98198  98208  98226  98270  98502  98632  \
# Region              ...
# Central          0  ...      0      0      0      0      0      0      0
# East             3  ...      0      0      0      0      0      0      0
# South            0  ...      0      0      0      0      0      0      0
# West             0  ...    111      7      1      3      2      5      3
#
# Postal Code  98661  99207  99301
# Region
# Central          0      0      0
# East             0      0      0
# South            0      0      0
# West             5      7      6
#
# ...

# %%
pd.crosstab(index=df['Segment'], columns=df['Ship Mode'])
# Out:
# Ship Mode    First Class  Same Day  Second Class  Standard Class
# Segment
# Consumer             768       317          1019            3079
# Corporate            485       114           608            1808
# Home Office          284       111           316            1068

# %%
pd.crosstab(index=df['City'], columns=df['Sub-Category'])
# Out:
# Sub-Category  Accessories  Appliances  Art  Binders  Bookcases  Chairs  \
# City
# Aberdeen                0           0    0        0          0       0
# Abilene                 0           1    0        0          0       0
# Akron                   2           0    2        5          0       0
# Albuquerque             2           0    1        1          0       0
# Alexandria              0           0    2        0          0       0
# ...                   ...         ...  ...      ...        ...     ...
# Woonsocket              0           0    0        1          0       0
# Yonkers                 2           0    1        3          0       0
# York                    0           0    0        2          0       1
# Yucaipa                 0           0    1        0          0       0
# Yuma                    1           0    1        1          0       0
#
# Sub-Category  Copiers  Envelopes  Fasteners  Furnishings  Labels  Machines  \
# City
# ...

# %%
import seaborn as sb

# %%
sb.histplot(df['Sales'],bins=80,kde=True)
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
sb.distplot(df['Sales'],bins=80,kde=True)
# Out:
# C:\Users\Rahul Soni\AppData\Local\Temp\ipykernel_14768\1180792558.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(df['Sales'],bins=80,kde=True)
# <Axes: xlabel='Sales', ylabel='Density'>

# %%
sb.boxplot(x=df['Quantity'], y=df['Sales'])
# Out:
# <Axes: xlabel='Quantity', ylabel='Sales'>

# %%
sb.scatterplot(x=df['Quantity'], y=df['Sales'])
# Out:
# <Axes: xlabel='Quantity', ylabel='Sales'>

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(df['Quantity'], df['Sales'])
plt.xlabel('Quantity')
plt.ylabel('Sales')
# plt.show()
# Out:
# Text(0, 0.5, 'Sales')

# %%
plt.scatter(df['Quantity'], df['Sales'])
